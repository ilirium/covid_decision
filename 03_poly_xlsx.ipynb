# %% [markdown]
# # Init

# %%
# %reload_ext autoreload
# %autoreload 2

# %config InlineBackend.figure_format = 'retina' # High-resolution plot outputs for Retina laptops

# %%
# Batteries
from datetime import datetime, timedelta
from pathlib import Path

# Externals
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# App
from dataset import get_data
from dataset import create_x
from linear import predict_lr
from poly import predict_poly

# %% [markdown]
# # Experiment

# %%
path = Path('daily_national_incidence_2020-08-19.xlsx')
df = pd.read_excel(path)

# %%
df
# Out:
#            country country_code continent  population        indicator  \
# 0      Afghanistan          AFG      Asia    38928341  confirmed cases
# 1      Afghanistan          AFG      Asia    38928341  confirmed cases
# 2      Afghanistan          AFG      Asia    38928341  confirmed cases
# 3      Afghanistan          AFG      Asia    38928341  confirmed cases
# 4      Afghanistan          AFG      Asia    38928341  confirmed cases
# ...            ...          ...       ...         ...              ...
# 99263     Zimbabwe          ZWE    Africa    14862927           deaths
# 99264     Zimbabwe          ZWE    Africa    14862927           deaths
# 99265     Zimbabwe          ZWE    Africa    14862927           deaths
# 99266     Zimbabwe          ZWE    Africa    14862927           deaths
# 99267     Zimbabwe          ZWE    Africa    14862927           deaths
#
#        daily_count       date  rate_14_day  \
# 0                0 2020-01-02          NaN
# 1                0 2020-01-03          NaN
# 2                0 2020-01-04          NaN
# 3                0 2020-01-05          NaN
# 4                0 2020-01-06          NaN
# ...            ...        ...          ...
# 99263            0 2020-08-15     4.104171
# 99264            2 2020-08-16     4.104171
# 99265            2 2020-08-17     4.171453
# 99266            3 2020-08-18     3.700482
# 99267            6 2020-08-19     4.036890
#
#                                            source
# 0      Epidemic intelligence, national daily data
# 1      Epidemic intelligence, national daily data
# 2      Epidemic intelligence, national daily data
# 3      Epidemic intelligence, national daily data
# 4      Epidemic intelligence, national daily data
# ...                                           ...
# 99263  Epidemic intelligence, national daily data
# 99264  Epidemic intelligence, national daily data
# 99265  Epidemic intelligence, national daily data
# 99266  Epidemic intelligence, national daily data
# 99267  Epidemic intelligence, national daily data
#
# [99268 rows x 9 columns]

# %% [markdown]
# # Flow

# %% [markdown]
# ## Load XLSX

# %%
path = Path('daily_national_incidence_2020-08-19.xlsx')
df = pd.read_excel(path)

# %% [markdown]
# ## Turkey

# %%
country = 'Turkey'
dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.033032895514776506
# RMSE = 2.450005676143461

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.20496621712420804
# RMSE = 2.2215394620539795

# %% [markdown]
# ## Germany

# %%
country = 'Germany'
dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.5231455510585277
# RMSE = 2.0912133767728207

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.8124340188998297
# RMSE = 1.3115427932066626

# %% [markdown]
# ## Latvia

# %%
country = 'Latvia'
dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.39831185777197853
# RMSE = 0.813410365360914

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.7320770025385911
# RMSE = 0.5427864189802621

# %% [markdown]
# ## Norway

# %%
country = 'Norway'

dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.2190312033742815
# RMSE = 2.2362697522068493

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.6745907147953247
# RMSE = 1.4435183831010665

# %% [markdown]
# ## UK

# %%
country = 'United Kingdom'

dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.5237860536984673
# RMSE = 4.382232056712854

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.9852079033638557
# RMSE = 0.7723411672958707

# %% [markdown]
# ## France

# %%
country = 'France'

dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.5926620031519783
# RMSE = 4.65944305485093

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.9517751404243349
# RMSE = 1.6032159783418416

# %% [markdown]
# ## Cyprus

# %%
country = 'Cyprus'

dt_range = ('2020-06-01', '2020-09-01')
len_predict = 4

days_fr, rate_14_day = get_data(df, country, dt_range)
X, X_pred, x_days = create_x(days_fr, len_predict)
y = rate_14_day

predict_lr(country, X, y, X_pred, x_days)
# Out:
# R2 score = 0.4910865860969992
# RMSE = 5.272337418845781

# %%
predict_poly(country, X, y, X_pred, x_days, degree=2)
# Out:
# R2 score = 0.9029486451301791
# RMSE = 2.30240674408309
